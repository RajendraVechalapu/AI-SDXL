# %%
# !python "/content/drive/MyDrive/Colab Notebooks/PythonTest.py"
# Out:
# Hello World: Test
# This is Rajendra Simhadri Appala Naidu

# %%
pip install -r "/content/drive/MyDrive/Colab Notebooks/requirements.txt"

# %%
streamlit run "/content/drive/MyDrive/Colab Notebooks/main.py"
# Out:
#   File "<ipython-input-8-9b211d1f30c1>", line 1
#     streamlit run "/content/drive/MyDrive/Colab Notebooks/main.py"
#               ^
# SyntaxError: invalid syntax
